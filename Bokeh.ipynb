# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d186f1a4-b6df-4bdb-b7a5-1075590eb1fb">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure, output_file, show
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
p.scatter(
    flowers['petal_length'],
    flowers['petal_width'],
    size=5
)
show(p)
# Out:
#   <div id="ee592325-26b1-4e63-9a03-715cdc8c3722" data-root-id="p1265" style="display: contents;"></div>

# %%
p.line(
    flowers['petal_length'],
    flowers['petal_width'],
    line_width=2
)
show(p)
# Out:
#   <div id="a96235ba-d26c-433f-af26-fae55e6e6487" data-root-id="p1265" style="display: contents;"></div>

# %%
x=[1,2,3,4]
y=[3,8,4,7]

p=figure(title="line_chart")
p.line(x,y, line_width=3)
show(p)
# Out:
#   <div id="eb86e604-495d-4d40-ba8a-8814a3f1bf52" data-root-id="p1008" style="display: contents;"></div>

# %%
x=[1,2,3,4]
y=[3,8,4,7]

p=figure(title="line_chart")
p.scatter(x,y, size=20, fill_color='red', legend_label="This is my data")
show(p)
# Out:
#   <div id="e8e0955b-360b-40d1-8b70-23fd103f1334" data-root-id="p1100" style="display: contents;"></div>
